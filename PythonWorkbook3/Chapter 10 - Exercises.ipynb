# %% [markdown]
# Exercise 1

# %%
tuple = (1, 1, 2, 3, 5)


result = sum(tuple)


print("Sum:", result)
# Out:
# Sum: 12

# %% [markdown]
# Exercise 2

# %%
country, capital, millions = ('Philippines', 'Manila', 103.3)


print("Country:", country)
print("Capital:", capital)
print("Population (Millions):", millions)
# Out:
# Country: Philippines
# Capital: Manila
# Population (Millions): 103.3
