# %% [markdown]
# Exercise 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Print('Hello world!') - the function print started in a capital letter
print('Hello world!')
# Out:
# Hello world!

# %%
#print'Hello world!') - Missing open parenthesis
print('Hello world!')
# Out:
# Hello world!

# %%
#print('Hello world!) - missing single qoute resulted to failure of terminating string literal
print('Hello world!')
# Out:
# Hello world!

# %%
#print('Hello world!'') - since there is an excess single qoute this  line of code was not able to determine that the string literal is being terminated
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)

# Since the the value of x is 43 and then a calculation made that x is added by 1 then the expected output is 44
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = X + 1
print(x)

# the variable name was named in a small letter x and a value was initialized there, an error occured because the variable name used during the calculation is not the variable name used during the initialization
