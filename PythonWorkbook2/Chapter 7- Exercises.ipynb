# %% [markdown]
# Exercise 1

# %%
filename = input('Enter a filename:')

try:
   with open(filename, 'r') as file:

        for line in file:
            print(line.upper(), end='')
except FileNotFoundError:
    print("File does not exist")
# Out:
# Enter a filename:docz
# File does not exist

# %% [markdown]
# Exercise 2

# %%
def count(f_path):
    try:
        with open(f_path, 'r') as file:
            line = sum(1 for line in file)
        return line
    except FileNotFoundError:
        print("File does not exist")
        return None

def main():
    path = input("Enter the file path: ")
    line_count = count(path)
    if line_count is not None:
        print("Number of lines in the file:", line_count)

if __name__ == "__main__":
    main()
# Out:
# Enter the file path: docs
# File not found.

# %% [markdown]
# Challenge

# %%
def s_pattern(file_path, p):
    try:
        with open(file_path, 'r') as file:
            for line_number, line in enumerate(file, start=1):
                if pattern in line:
                    print(f"Line {line_number}: {line.strip()}")
    except FileNotFoundError:
        print("File does not exist")

def main():
    file = input("Enter the file name: ")
    pattern = input("Enter the pattern to search for: ")
    print(f"Searching for lines containing '{pattern}' in file '{file}':")
    s_pattern(file, s_pattern)

if __name__ == "__main__":
    main()
# Out:
# Enter the file name: docs
# Enter the pattern to search for: []
# Searching for lines containing '[]' in file 'docs':
# File not found.
